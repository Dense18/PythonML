# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
df = pd.DataFrame(data = iris.data, columns = iris.feature_names)
df["target"] = pd.Series(iris.target)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ..      ...
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
#
# [150 rows x 5 columns]

# %%
X, y = iris.data[:,0:2],iris.data[:,0]
# X = X.reshape(-1,1)

# %%
reg = LinearRegression().fit(X, y)

# %%
reg.coef_
# Out:
# array([ 1.00000000e+00, -5.49189316e-17])

# %%
sx  = df.iloc[:,0:2]
sy = df.iloc[:,1]

sx = sm.add_constant(sx)
model = sm.OLS(sy, sx).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       sepal width (cm)   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.885e+30
# Date:                Sat, 01 Jul 2023   Prob (F-statistic):               0.00
# Time:                        15:09:19   Log-Likelihood:                 4818.3
# No. Observations:                 150   AIC:                            -9631.
# Df Residuals:                     147   BIC:                            -9622.
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const             -3.691e-15   2.39e-15     -1.546      0.124   -8.41e-15    1.03e-15
# sepal length (cm)  6.176e-16   2.73e-16      2.262      0.025    7.81e-17    1.16e-15
# sepal width (cm)      1.0000   5.19e-16   1.93e+15      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                        3.197   Durbin-Watson:                   0.080
# Prob(Omnibus):                  0.202   Jarque-Bera (JB):                2.708
# Skew:                          -0.302   Prob(JB):                        0.258
# Kurtosis:                       3.263   Cond. No.                         72.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sx  = df.iloc[:,1]
sy = df.iloc[:,1]

sx = sm.add_constant(sx)
model = sm.OLS(sy, sx).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       sepal width (cm)   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.284e+32
# Date:                Sat, 01 Jul 2023   Prob (F-statistic):               0.00
# Time:                        15:09:02   Log-Likelihood:                 5125.6
# No. Observations:                 150   AIC:                        -1.025e+04
# Df Residuals:                     148   BIC:                        -1.024e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const            -4.441e-16   2.04e-16     -2.173      0.031   -8.48e-16   -4.03e-17
# sepal width (cm)     1.0000   6.62e-17   1.51e+16      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                     5389.719   Durbin-Watson:                   0.645
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               16.506
# Skew:                           0.278   Prob(JB):                     0.000260
# Kurtosis:                       1.473   Cond. No.                         24.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model.predict(sx)
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Length: 150, dtype: float64
